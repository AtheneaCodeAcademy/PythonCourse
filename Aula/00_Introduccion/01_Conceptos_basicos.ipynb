# %% [markdown]
# # `Conceptos básicos`
# ---
# ## 🔍 ¿Con qué trabajaremos?
# En programación, trabajamos con **información**. Todo lo que hacemos, ya sea mostrar un resultado por pantalla, guardar datos en un archivo, enviar un mensaje, o realizar un cálculo, involucra **manipular datos**.
#
# La **unidad mínima de la información** en programación es el **dato**. Todo programa, sin importar su complejidad, se basa en la creación, procesamiento y transformación de datos.
#
# <p align="center">
#   <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExOGM5YmZzZmFlaGV1eXhwNXFwaGl0MWFjcXI0bGdwNjF2ODV6M2N6dSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/VeT5jhseHD0W3dI7de/giphy.gif" width="300">
# </p>
#
# ## 📊 ¿Qué es un dato?
# Un **dato** es un **valor** que **representa algo concreto**: un número, una palabra, una fecha, una decisión (sí o no), etc.
#
# | Hecho                                   | Dato (valor)            | Tipo de dato    |
# | ----------------------------------------| ------------------------| --------------- |
# | Saludo                                  | 'Hola'                  | Cadena de texto |
# | Años de tu herman@                      | 33                      | Número entero   |
# | Número Pi                               | 3.1415...               | Número decimal  |
# | Fecha de nacimiento de tu pareja        | 1997-05-02              | Fecha           |
# | ¿És mi profesor de Python el mejor?     | True (Verdadero)        | Booleano        |
#
# ## Tipos de datos en Python
# En Python, cada **dato **pertenece a un **tipo de dato**. El tipo de dato nos indica qué tipo de información contiene y qué operaciones podemos hacer con ella.
#
# - `Escalares o Primitivos`
#
# | Tipo       | Ejemplo         | Descripción                                 |
# | ---------- | --------------- | ------------------------------------------- |
# | **int**      | `1`             | Números enteros                             |
# | **float**    | `3.14`          | Números decimales                           |
# | **bool**     | `True`          | Valores lógicos (binarios)                  |
# | **str**      | `"Hola"`        | Cadenas de texto (secuencias de caracteres) |
# | **complex**  | `1+2j`          | Números complejos (usados raramente)        |
# | **NoneType** | `None`          | Representa la ausencia de valor             |
#
# - `Colecciones o Estructuras de datos, Conjuntos y Mapas`
#
# | Tipo    | Ejemplo     | Descripción                        |
# | ------- | ----------- | -----------------------------------|
# | `list`  | `[1, 2, 3]` | Lista                              |
# | `tuple` | `(1, 2, 3)` | Tupla                              |
# | `range` | `range(5)`  | Secuencia de enteros               |
# | `set`   | `{1, 2, 3}` | Conjunto                           |
# | `dict`  | `{"nombre": "Lionel", "edad": 35}` | Diccionario |
#
# ## ¿Qué es un objeto en Python?
# Python es un lenguaje **orientado a objetos**, lo que significa que **todo** en Python es un **objeto**.
# Un **objeto** es una estructura en memória que contiene:
# - **Tipo** (`int`, `str`, `list`, `dict` y un infinito etcétera...)
# - **Valor** (contenido del objeto)
# - **Atributos** y **métodos** (carácterísticas y funciones asociadas al objeto)
# - **Identificador** (dirección de memória)
