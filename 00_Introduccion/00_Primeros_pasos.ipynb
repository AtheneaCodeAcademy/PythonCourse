# %% [markdown]
# # 🥳 ¡Bienvenid@ a tu primera clase! 🥳
#
# <p align="center">
#   <img src="https://media.giphy.com/media/a1QLZUUtCcgyA/giphy.gif" width="300">
# </p>
#
# ## ¿Qué es Python? 🐍
# - Es un lenguaje de programación de **alto nivel**, lo que significa que su escritura y lectura es más próxima al lenguaje humano que al lenguaje máquina.
# - Es un lenguaje de **tipado dinámico**, no es necesario declarar el tipo de dato de una variable, el mismo lenguaje lo detecta y modifica en tiempo de ejecución.
# - **No necesita compilarse**, se ejecuta línea a línea mediante un intérprete.
# - Es **multiplataforma**, se puede usar en *Windows*, *macOS* y *Linux*.
#
# `En resumen Python es un lenguaje moderno, sencillo y versátil ideal para aprender a programar y desarollar proyectos sencillos y complejos.`
#
# ---
#
# ## Usos/Aplicaciones 🔧
# - Automatización de tareas
# - Análisis y ciéncia de datos
# - Desarrollo web
# - Aplicaciones de escritorio
# - Programación de APIs
# - Desarrollo de videjuegos
# - Ciberseguridad
#
# ---
#
# ## ¿Qué es un script? 📄
# Es un archivo de texto que contiene un **conjunto de instrucciones** en un lenguaje de programación (Python) que se ejecutan de **forma secuencial** (una línea de código detrás de la otra).
#
# En nuestro caso, ejecutaremos tanto *scripts* de Python como *Jupyter Notebooks*, ambos recursos los ejecutaremos dentro de un entorno completo llamado **Jupyter Lab**.
#
# ---
#
# ## Script 🆚 Jupyter Notebook
#
# - `Script (.py)`:
#   - Es un archivo de **texto plano** con extensión `.py`.
#   - Contiene código Python que se ejecuta de principio a fin, de **forma secuencial**.
#   - Se usa comúnmente en entornos de desarrollo como *VSCode*, *PyCharm* o desde la *terminal*.
#   - Ideal para escribir programas completos, **automatizaciones** o **funciones reutilizables**.
#   - Solo permite incluir comentarios simples usando #, no permite mezclar texto explicativo o visualizaciones de forma interactiva.
#   - **No puedes ejecutar partes aisladas fácilmente**, salvo que dividas el código en funciones.
# - `Jupyter Notebook (.ipynb)`:
#   - Un archivo con extensión `.ipynb` que se abre desde el navegador.
#   - Está **dividido en celdas**, lo que permite ejecutar el código de manera **interactiva** y **por partes**.
#   - Permite combinar código Python, texto explicativo (**Markdown**), imágenes y gráficos.
#   - Puedes modificar y volver a ejecutar cualquier celda sin reiniciar todo el código.
#
# ---
#
# ## Primeros pasos 🫂
# - Ejecución de celdas
# - Objetos
# - Tipos de datos
# - Funciones In-Build
